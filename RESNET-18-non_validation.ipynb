# %%
from __future__ import print_function, division

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from mpl_toolkits.axes_grid1 import ImageGrid
plt.ion()  

use_gpu = torch.cuda.is_available()
if use_gpu:
    print("Using CUDA")
# Out:
# Using CUDA

# %%
torch.manual_seed(0)

# %%
data_dir = "/scratch/mk7711/dast/datasets/traditional+og/wd/"
train = 'train'
test = 'test'

data_transforms = {
    train: transforms.Compose([
        # Data augmentation is a good practice for the train set
        # Here, we randomly crop the image to 224x224 and
        # randomly flip it horizontally. 
        #transforms.RandomResizedCrop(224),
        #transforms.RandomHorizontalFlip(),
        #transforms.RandomVerticalFlip(),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    test: transforms.Compose([
        #transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

image_datasets = {
    x: datasets.ImageFolder(
        os.path.join(data_dir, x), 
        transform=data_transforms[x]
    )
    for x in [train, test]
}

dataloaders = {
    x: torch.utils.data.DataLoader(
        image_datasets[x], batch_size=32,
        shuffle=True, num_workers=4
    )
    for x in [train, test]
}
print(len(dataloaders['train']))

dataset_sizes = {x: len(image_datasets[x]) for x in [train, test]}

for x in [train, test]:
    print("Loaded {} images under {}".format(dataset_sizes[x], x))
    
print("Classes: ")
class_names = image_datasets[train].classes
print(image_datasets[train].classes)
# Out:
# 243
# Loaded 7758 images under train
# Loaded 2817 images under test
# Classes:
# ['back_pack', 'bike', 'bike_helmet', 'bookcase', 'bottle', 'calculator', 'desk_chair', 'desk_lamp', 'desktop_computer', 'file_cabinet', 'headphones', 'keyboard', 'laptop_computer', 'letter_tray', 'mobile_phone', 'monitor', 'mouse', 'mug', 'paper_notebook', 'pen', 'phone', 'printer', 'projector', 'punchers', 'ring_binder', 'ruler', 'scissors', 'speaker', 'stapler', 'tape_dispenser', 'trash_can']

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs)
imshow(out)

# %%
def train_model(dataloders, model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    use_gpu = torch.cuda.is_available()
    best_acc = 0.0
    dataset_sizes = {'train': len(dataloders['train'].dataset)}

    for epoch in range(num_epochs):
        for phase in ['train']:
            if phase == 'train':
                scheduler.step()
                model.train()
            else:
                model.train() #changed here to true

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloders[phase]:
                if use_gpu:
                    inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
                else:
                    inputs, labels = Variable(inputs), Variable(labels)

                optimizer.zero_grad()

                outputs = model(inputs)
                _, preds = torch.max(outputs.data, 1)
            
                loss = criterion(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                running_loss += loss.data
                running_corrects += torch.sum(preds == labels.data)
            
            if phase == 'train':
                train_epoch_loss = running_loss / dataset_sizes[phase]
                train_epoch_acc = running_corrects / dataset_sizes[phase]
            else:
                valid_epoch_loss = running_loss / dataset_sizes[phase]
                valid_epoch_acc = running_corrects / dataset_sizes[phase]
                

        print('Epoch [{}/{}] train loss: {:.4f} acc: {:.4f} ' 
              .format(
                  epoch, num_epochs - 1,
                train_epoch_loss, train_epoch_acc
                ))
    torch.save(model.state_dict(),"50_epochs.pth")
    return model

# %%
def eval_model(model, criterion):
    since = time.time()
    avg_loss = 0
    avg_acc = 0
    loss_test = 0
    acc_test = 0
    
    test_batches = len(dataloaders[test])
    print("Evaluating model")
    print('-' * 10)
    
    for i, data in enumerate(dataloaders[test]):
        if i % 100 == 0:
            print("\rTest batch {}/{}".format(i, test_batches), end='', flush=True)

        model.train(False)
        model.eval()
        inputs, labels = data

        if use_gpu:
            with torch.no_grad():
                inputs, labels = inputs.cuda(),labels.cuda()
                #inputs, labels = Variable(inputs.cuda(), volatile=True), Variable(labels.cuda(), volatile=True)
        else:
            inputs, labels = Variable(inputs, volatile=True), Variable(labels, volatile=True)

        outputs = model(inputs)

        _, preds = torch.max(outputs.data, 1)
        loss = criterion(outputs, labels)

        loss_test += loss.data
        acc_test += torch.sum(preds == labels.data)

        del inputs, labels, outputs, preds
        torch.cuda.empty_cache()
        #gc.collect()
        
    avg_loss = loss_test / dataset_sizes[test]
    avg_acc = acc_test / dataset_sizes[test]
    
    elapsed_time = time.time() - since
    print()
    print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
    print("Avg loss (test): {:.4f}".format(avg_loss))
    print("Avg acc (test): {:.4f}".format(avg_acc))
    print('-' * 10)

# %%
#for pre-trained model
model = models.resnet18(pretrained=True)
# freeze all model parameters
for param in model.parameters():
    param.requires_grad = False

# %%
#for non pre-trained model
model = models.resnet18(pretrained=False)

# %%
# new final layer with 16 classes
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 31)

# %%
model = model.cuda()

#resnet.load_state_dict(torch.load("50_epochs.pth"))
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.5,0.999), weight_decay=0.001)
#optimizer = torch.optim.SGD(resnet.parameters(), lr=0.01, weight_decay=0.001)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1)
dloaders = {'train':dataloaders['train']}
# Out:
# <generator object Module.parameters at 0x7f4bae3b9b30>
# <generator object Module.parameters at 0x7f4bae3b9b30>

# %%
start_time = time.time()
model = train_model(dloaders, model, criterion, optimizer, exp_lr_scheduler, num_epochs=50)
print('Training time: {:10f} minutes'.format((time.time()-start_time)/60))
# Out:
# /home/mk7711/.local/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch [0/49] train loss: 0.0766 acc: 0.3188
# Epoch [1/49] train loss: 0.0512 acc: 0.5416
# Epoch [2/49] train loss: 0.0398 acc: 0.6513
# Epoch [3/49] train loss: 0.0322 acc: 0.7218
# Epoch [4/49] train loss: 0.0277 acc: 0.7615
# Epoch [5/49] train loss: 0.0256 acc: 0.7805
# Epoch [6/49] train loss: 0.0237 acc: 0.7967
# Epoch [7/49] train loss: 0.0232 acc: 0.8020
# Epoch [8/49] train loss: 0.0217 acc: 0.8126
# Epoch [9/49] train loss: 0.0217 acc: 0.8140
# Epoch [10/49] train loss: 0.0224 acc: 0.8069
# Epoch [11/49] train loss: 0.0208 acc: 0.8175
# Epoch [12/49] train loss: 0.0211 acc: 0.8166
# Epoch [13/49] train loss: 0.0203 acc: 0.8229
# Epoch [14/49] train loss: 0.0207 acc: 0.8201
# Epoch [15/49] train loss: 0.0208 acc: 0.8171
# Epoch [16/49] train loss: 0.0205 acc: 0.8216
# Epoch [17/49] train loss: 0.0205 acc: 0.8234
# Epoch [18/49] train loss: 0.0195 acc: 0.8288
# Epoch [19/49] train loss: 0.0199 acc: 0.8247
# Epoch [20/49] train loss: 0.0217 acc: 0.8114
# Epoch [21/49] train loss: 0.0199 acc: 0.8280
# Epoch [22/49] train loss: 0.0206 acc: 0.8198
# Epoch [23/49] train loss: 0.0198 acc: 0.8270
# Epoch [24/49] train loss: 0.0191 acc: 0.8322
# Epoch [25/49] train loss: 0.0189 acc: 0.8335
# Epoch [26/49] train loss: 0.0226 acc: 0.8032
# Epoch [27/49] train loss: 0.0196 acc: 0.8291
# Epoch [28/49] train loss: 0.0197 acc: 0.8273
# Epoch [29/49] train loss: 0.0193 acc: 0.8305
# Epoch [30/49] train loss: 0.0192 acc: 0.8311
# Epoch [31/49] train loss: 0.0201 acc: 0.8269
# Epoch [32/49] train loss: 0.0198 acc: 0.8270
# Epoch [33/49] train loss: 0.0193 acc: 0.8333
# Epoch [34/49] train loss: 0.0199 acc: 0.8243
# Epoch [35/49] train loss: 0.0194 acc: 0.8293
# Epoch [36/49] train loss: 0.0204 acc: 0.8230
# Epoch [37/49] train loss: 0.0191 acc: 0.8338
# Epoch [38/49] train loss: 0.0189 acc: 0.8340
# Epoch [39/49] train loss: 0.0187 acc: 0.8369
# Epoch [40/49] train loss: 0.0182 acc: 0.8394
# Epoch [41/49] train loss: 0.0181 acc: 0.8396
# Epoch [42/49] train loss: 0.0181 acc: 0.8399
# Epoch [43/49] train loss: 0.0180 acc: 0.8412
# Epoch [44/49] train loss: 0.0181 acc: 0.8399
# Epoch [45/49] train loss: 0.0180 acc: 0.8406
# Epoch [46/49] train loss: 0.0180 acc: 0.8408
# Epoch [47/49] train loss: 0.0180 acc: 0.8408
# Epoch [48/49] train loss: 0.0179 acc: 0.8409
# Epoch [49/49] train loss: 0.0180 acc: 0.8407
# Training time:  32.045268 minutes

# %%
eval_model(model, criterion)
# Out:
# Evaluating model
# ----------
# Test batch 0/89
# Evaluation completed in 0m 5s
# Avg loss (test): 0.1658
# Avg acc (test): 0.0816
# ----------
